# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.

x_axis = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 'July', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec']

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.

y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()

fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()

fig = plt.figure()

ax = fig.add_subplot()

ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()

ax = plt.axes()

ax.plot(x_axis, y_axis)

# %%
# Create the plot.

plt.plot(x_axis, y_axis)

plt.show()

# %%
# Create the plot and add a label for the legend.

plt.plot(x_axis, y_axis, marker='d', color ='green', linewidth=2, label='Boston')

# Create labels for the x and y axes.

plt.xlabel('Date')
plt.ylabel('Fare($)')

# Set the y limit between 0 and 45.

plt.ylim(0, 45)

# Create a title.

plt.title('PyBer Fare by Month')

# Add grid

plt.grid()

# Add the legend.

plt.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create a bar chart

plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot

plt.bar(x_axis, y_axis, color='green', label='Boston')

# Create labels for the x and y axes

plt.xlabel('Date')
plt.ylabel('Fare($)')

# Create a Title

plt.title('PyBer Fare by Month')

# Add Legend

plt.legend()

# %%
# Create the plot for a horizontal chart use 'plt.barh()'

plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Switching the axes in the bar statement, switch the axes i.e y_axis, x_axis

plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# To invert the y-axis to have the months in ascending order, use the gca() method. 
# The gca() method means "get current axes." We can chain the gca() method to the invert_yaxis() 
# method by using gca().invert_yaxis(), as shown here:

# Create the plot.

plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
# Skill Drill

# 1. Change the bar colors to magenta.

# 2. Add a legend for the city of Boston.

# 3. Add a title and axes labels.

# 4. Invert the y-axis so that January is at the top.

plt.barh(x_axis, y_axis, color='Magenta', label='Boston')

plt.xlabel('Fare($)')
plt.ylabel('Date')

plt.title('PyBer Fare by Month')

plt.gca().invert_yaxis()

plt.legend()

# %%
# Create Bar Charts Using the Object-Oriented Approach

# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot with ax.plt()

fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create a horizontal bar chart using the object-oriented interface method, use the ax.barh() function.

# Create the plot with ax.plt()

fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Skill Drill

# 1. Change the bar color to cyan.
        # color='cyan'
# 2. Add a legend for the city of Chicago.
        # label='Chicago'
        # plt.legend()
# 3. Add a title and axes labels.
        # plt.title('PyBer Fare by month')
# 4. Switch the axis so that the Fare($) data is on the x-axis.
        # plt.xlabel('Fare($)')
        #plt.ylabel('Date')
# 5. Invert the y-axis data.
        # plt.gca().invert_yaxis()

plt.barh(x_axis, y_axis, color='cyan', label='Chicago')

plt.xlabel('Fare($)')
plt.ylabel('Date')

plt.title('PyBer Fare by month')

plt.legend()

plt.gca().invert_yaxis()

# %%
# Scatter Plots - when changing to a scatter plot we place a 'o' 
# inside the parenthesis = 'plt.plot(x_axis, y_axis, 'o')'

# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

plt.plot(x_axis, y_axis, 'o')

# %%
# To create a scatter plot using the plt.scatter() function, 
# add the x-axis and y-axis parameters inside the parentheses = 'plt.scatter(x_axis, y_axis)'

# Skill Drill

    # 1. Change the color of the markers to red.
            # color='Red'
    # 2. Add a legend for the city of Chicago.
            # label='Chicago'
            # plt.legend()
    # 3. Add a title and axes labels.
            # plt.title('PyBer Fare by Month')
    # 4. Switch the axis so that the Fare($) data is on the x-axis.
            # plt.xlabel('Fare ($)')
            # plt.ylabel('Date')
    # 5. Add a limit for the x-axis data.
            # s=50
    # 6. Invert the y-axis so that January is at the top.
            # plt.gca().invert_yaxis()

plt.scatter(y_axis, x_axis, color='Red', label='Chicago', s=50)

plt.xlabel('Fare ($)')
plt.ylabel('Date')

plt.title('PyBer Fare by Month')
plt.legend()

plt.gca().invert_yaxis()

# %%
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
# We can adjust the size by multiplying the data in the y-axis by any value. 
# Let's multiply each data point in the y-axis by 3 and see what happens. 
# To do this, we can iterate through the y-axis data and multiply each data point by 3

y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)
    
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
# List comperhension technique can replace the 'for' or 'while' loop.
        # new_list = [expression for item in list if conditional]

plt.scatter(x_axis, y_axis, s= [i * 3 for i in y_axis])

# %%
# Create a Scatter Plot Using the Object-Oriented Interface

fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
# Create a Bubble Chart Using the Object-Oriented Interface

fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %%
# Skill Drill  Using the object-oriented approach, make the following changes to your bubble chart:

        # 1. Change the color of the markers to sky blue.
                # ax.scatter(x_axis, y_axis, color='sky blue', s=y_axis)
        # 2. Change the size of the markers to 5 times each data point.
                # ax.scatter(x_axis, y_axis, s= [i * 5 for i in y_axis])
        # 3. Make the color 20% transparent.
        
    #ask the TA

        # 4. Add a black edge color to the circles.
        
    #ask the TA

        # 5. Make the linewidth of the circles 2 points.
    # 'LineWidth, 2'
        # 6. Add a legend for the city of Boston.
                # label ='Boston'
                # plt.legend()
        # 7. Add a title.
                # PyBer Fare by Month
        # 8. Switch the axis so that the Fare($) data is on the x-axis.
                # x.scatter(y_axis, x_axis) change the position of the x, y
                # plt.xlabel('Fare ($)')
                # plt.ylabel('Date')

        # 9. Add a limit for the x_axis data.
    # ask the TA     
        # 10. Invert the y-axis so that January is at the top.
                # plt.gca().invert_yaxis()
        
        
     
fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis, color='skyblue', label='Boston', s= [i * 5 for i in y_axis])

plt.title('PyBer Fare by Month')
plt.xlabel('Fare ($)')
plt.ylabel('Date')
plt.legend()

plt.gca().invert_yaxis()

# %%
# Create a Pie Chart Using the MATLAB Method

plt.pie(y_axis, labels=x_axis)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)

plt.subplots(figsize=(8, 8))

plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')

plt.show()

# %%
 # Assign 12 colors, one for each month.

colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", 
          "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]

explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)

plt.subplots(figsize=(8, 8))

plt.pie(y_axis, 
        explode=explode_values, 
        colors=colors,
        labels=x_axis, 
        autopct='%.1f%%')

plt.show()

# %%
# Create a Pie Chart Using the Object-Oriented Interface

colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", 
          "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]

explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)

plt.subplots(figsize=(8, 8))

plt.pie(y_axis, 
        explode=explode_values, 
        colors=colors,
        labels=x_axis, 
        autopct='%.1f%%')

fig, ax = plt.subplots()

ax.pie(y_axis, labels=x_axis)

plt.show()

# %%
# Skill Drill

       # 1. Add a percentage to one decimal place to each wedge of the pie.
            # plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%'
       # 2. Increase the figure size to 8x8.
            # plt.subplots(figsize=(8, 8))
       # 3. Explode the two highest percentage months.
            # explode_values = (0, 0, 0, 0, 0, 0.2, 0.2, 0, 0, 0, 0, 0)
       # 4. Add a shadow.
            # shadow=False
       # 5. Add a start angle so that January is at the top.
            # startangle=0
       # 6. Reverse the order so that the month order is in a clockwise direction.
            # counterclock=True
       # 7. Add new colors of your own choosing or use the colors from the previous pie chart
            # colors=colors.

colors = ["slateblue", "magenta", "lightblue", "green", "teal", "cyan", 
          "yellow", "red", "crimson", "indianred", "maroon", "mistyrose"]

explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)

plt.subplots(figsize=(8, 8))

plt.pie(y_axis, 
        explode=explode_values, 
        colors=colors,
        labels=x_axis,
        shadow=True,
        startangle=95,
        counterclock=False,
        autopct='%.1f%%')

plt.show()
